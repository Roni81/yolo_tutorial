# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# Setup complete ✅ (12 CPUs, 15.4 GB RAM, 115.0/467.3 GB disk)

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ultralytics.com/images/zidane.jpg locally at zidane.jpg
# image 1/1 /home/roni/dev_ws/yolo_tut/zidane.jpg: 384x640 2 persons, 1 tie, 56.3ms
# Speed: 3.5ms preprocess, 56.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /home/roni/dev_ws/yolo_tut/runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(data = "coco8.yaml", epochs = 10)

metrics = model.val()
results = model("https://ultralytics.com/images/bus.jpg")

path = model.export(format = "onnx")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...

# %%
# !yolo predict model=runs/detect/train/weights/best.pt source='./bus.jpg'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CPU (Intel Core i7-10750H 2.60GHz)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /home/roni/dev_ws/yolo_tut/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 67.5ms
# Speed: 2.4ms preprocess, 67.5ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/roni/dev_ws/yolo_tut/runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
model = YOLO("yolov8n-cls.pt")
results = model.predict("./Rock Paper Scissors.v1-raw-300x300.folder/v4-728px-Play-Rock-Paper-Scissors-Lizard-Spock-Step-1-Version-3.jpg",
                        save=True)
# Out:
# image 1/1 /home/roni/dev_ws/yolo_tut/Rock Paper Scissors.v1-raw-300x300.folder/v4-728px-Play-Rock-Paper-Scissors-Lizard-Spock-Step-1-Version-3.jpg: 224x224 Band_Aid 0.11, pick 0.06, remote_control 0.05, puck 0.03, rule 0.03, 3.1ms
# Speed: 5.2ms preprocess, 3.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /home/roni/dev_ws/yolo_tut/runs/classify/predict2

# %%
model = YOLO('yolov8n-cls.pt')
results = model.train(data='./Rock Paper Scissors.v1-raw-300x300.folder', epochs=10, imgsz=300)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...

# %%
model = YOLO('/home/roni/dev_ws/yolo_tut/runs/classify/train4/weights/best.pt')

results = model.predict(source = '/home/roni/dev_ws/yolo_tut/Rock Paper Scissors.v1-raw-300x300.folder/v4-728px-Play-Rock-Paper-Scissors-Lizard-Spock-Step-1-Version-3.jpg', save=True)
# Out:
# image 1/1 /home/roni/dev_ws/yolo_tut/Rock Paper Scissors.v1-raw-300x300.folder/v4-728px-Play-Rock-Paper-Scissors-Lizard-Spock-Step-1-Version-3.jpg: 320x320 rock 1.00, paper 0.00, scissors 0.00, 3.1ms
# Speed: 7.2ms preprocess, 3.1ms inference, 0.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to /home/roni/dev_ws/yolo_tut/runs/classify/predict3

# %%
model = YOLO('/home/roni/dev_ws/yolo_tut/runs/classify/train4/weights/best.pt')

source_path = '/home/roni/dev_ws/yolo_tut/Rock Paper Scissors.v1-raw-300x300.folder/v4-728px-Play-Rock,-Paper,-Scissors-Step-9-Version-4.jpg'

results = model.predict(source = source_path, save=True)
# Out:
# image 1/1 /home/roni/dev_ws/yolo_tut/Rock Paper Scissors.v1-raw-300x300.folder/v4-728px-Play-Rock,-Paper,-Scissors-Step-9-Version-4.jpg: 320x320 rock 0.92, scissors 0.05, paper 0.03, 2.6ms
# Speed: 4.5ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to /home/roni/dev_ws/yolo_tut/runs/classify/predict4

# %%
model = YOLO("yolov8n.pt")

source_path = "/home/roni/dev_ws/yolo_tut/datasets/classification_sample.jpg"

results = model.predict(source = source_path, conf = 0.2, save = True)

print(results)
# Out:
# image 1/1 /home/roni/dev_ws/yolo_tut/datasets/classification_sample.jpg: 384x640 6 cars, 1 bus, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /home/roni/dev_ws/yolo_tut/runs/detect/predict6
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
results = model.train(data='/home/roni/dev_ws/yolo_tut/datasets/Aquarium Combined/data.yaml', epochs = 25)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("/home/roni/dev_ws/yolo_tut/runs/detect/train9/weights/best.pt")

model.predict(source="https://youtu.be/k9OqZ79FWx0?si=qFS6u9h1L1yS2sfb", show = True)
# Out:
# <generator object BasePredictor.stream_inference at 0x766630702440>

# %%
import cv2

filepath = '/home/roni/dev_ws/yolo_tut/datasets/le-sserafim-reuserapim-crazy-official-mv_video_720p_original.mp4'
video = cv2.VideoCapture(filepath)

if not video.isOpened():
    print("Could not open : ", filepath)
    exit(0)

length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)

import os

#프레임을 저장할 디렉토리를 생성
try:
    if not os.path.exists(filepath[:-4]):
        os.makedirs(filepath[:-4])
except OSError:
    print ('Error: Creating directory. ' +  filepath[:-4])

num = input("How many frame want to get? :")

num = int(num)

div_num = length // num

count = 0

while True: # 혹은 while video.isOpened():
    ret, image = video.read()
    
    # [중요] 프레임을 제대로 읽지 못했다면(영상 끝 등) 반복문을 종료합니다.
    if not ret:
        print("더 이상 프레임이 없거나 읽을 수 없습니다. 종료합니다.")
        break

    # 프레임이 정상일 때만 아래 로직 실행
    if(int(video.get(1)) % div_num == 0): 
        # 주의: filepath[:-4] 경로에 해당하는 폴더가 실제로 존재해야 저장이 됩니다.
        cv2.imwrite(filepath[:-4] + "/frame%d.jpg" % count, image)
        print('Saved frame number :', str(int(video.get(1))))
        count += 1
# Out:
# length : 4075
# width : 1280
# height : 720
# fps : 23.976023976023978
# Saved frame number : 271
# Saved frame number : 542
# Saved frame number : 813
# Saved frame number : 1084
# Saved frame number : 1355
# Saved frame number : 1626
# Saved frame number : 1897
# Saved frame number : 2168
# Saved frame number : 2439
# Saved frame number : 2710
# Saved frame number : 2981
# Saved frame number : 3252
# Saved frame number : 3523
# Saved frame number : 3794
# Saved frame number : 4065
# 더 이상 프레임이 없거나 읽을 수 없습니다. 종료합니다.

# %%
from ultralytics import YOLO

# %%
yaml_path = '/home/roni/dev_ws/yolo_tut/datasets/race-highlights-2025-abu-dhabi-grand-prix_video_1080p50_english/json/YOLODataset/dataset.yaml'

# %%
model = YOLO('yolov8n.pt')
results = model.train(data=yaml_path , epochs = 25)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 2060, 5739MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("/home/roni/dev_ws/yolo_tut/runs/detect/train16/weights/best.pt")

model.predict(source="https://youtu.be/ajzQj7bjSWE?si=RHrnaCN5ogzfNuMt", show = True, stream = True)
# Out:
# <generator object BasePredictor.stream_inference at 0x737ae40f0280>

# %%
from ultralytics import YOLO

# 모델 로드
model = YOLO("/home/roni/dev_ws/yolo_tut/runs/detect/train16/weights/best.pt")

# 결과를 변수에 담고 반복문으로 실행
results = model.predict(source="https://youtu.be/S-LMSpzlnc0?si=ofh-WVCXVn7Wcor8", show=True, stream=True)

for result in results:
    pass  # 여기서 result를 이용해 필요한 작업(좌표 저장 등)을 수행하거나 그냥 흘려보냅니다.
# Out:
# 1/1: https://youtu.be/S-LMSpzlnc0?si=ofh-WVCXVn7Wcor8... Success ✅ (25133 frames of shape 1920x1080 at 50.00 FPS)
#
# 0: 384x640 (no detections), 10.4ms
# 0: 384x640 (no detections), 7.6ms
# 0: 384x640 (no detections), 5.9ms
# 0: 384x640 (no detections), 7.2ms
# 0: 384x640 (no detections), 11.2ms
# 0: 384x640 (no detections), 10.4ms
# 0: 384x640 (no detections), 11.3ms
# 0: 384x640 (no detections), 10.2ms
# 0: 384x640 (no detections), 10.0ms
# 0: 384x640 (no detections), 6.9ms
# 0: 384x640 (no detections), 11.1ms
# 0: 384x640 (no detections), 8.9ms
# 0: 384x640 (no detections), 7.3ms
# 0: 384x640 (no detections), 6.4ms
# 0: 384x640 (no detections), 8.8ms
# 0: 384x640 (no detections), 9.9ms
# 0: 384x640 (no detections), 10.4ms
# 0: 384x640 (no detections), 10.8ms
# 0: 384x640 (no detections), 9.6ms
# 0: 384x640 (no detections), 11.1ms
# 0: 384x640 (no detections), 10.1ms
# 0: 384x640 (no detections), 9.1ms
# 0: 384x640 (no detections), 10.1ms
# 0: 384x640 (no detections), 10.8ms
# ...

# %%
import os
import json
import shutil
import random
import yaml
from pathlib import Path
from ultralytics import YOLO

# 1. Configuration
SOURCE_DIR = '/home/roni/dev_ws/yolo_tut/datasets/le-sserafim-reuserapim-crazy-official-mv_video_720p_original'
DATASET_NAME = 'lesserafim'
BASE_DIR = f'/home/roni/dev_ws/yolo_tut/datasets/{DATASET_NAME}'
IMAGES_DIR = os.path.join(BASE_DIR, 'images')
LABELS_DIR = os.path.join(BASE_DIR, 'labels')

# Create directory structure
for split in ['train', 'val']:
    os.makedirs(os.path.join(IMAGES_DIR, split), exist_ok=True)
    os.makedirs(os.path.join(LABELS_DIR, split), exist_ok=True)

# 2. Convert LabelMe JSON to YOLO txt
classes = set()
data_pairs = []

# First pass to find all pairs and classes
for filename in os.listdir(SOURCE_DIR):
    if filename.endswith('.json'):
        json_path = os.path.join(SOURCE_DIR, filename)
        image_name = filename.replace('.json', '.jpg')
        image_path = os.path.join(SOURCE_DIR, image_name)
        
        if os.path.exists(image_path):
            data_pairs.append((json_path, image_path))
            # Extract classes
            with open(json_path, 'r') as f:
                data = json.load(f)
                for shape in data['shapes']:
                    classes.add(shape['label'])

class_list = sorted(list(classes))
class_to_id = {cls: i for i, cls in enumerate(class_list)}
print(f"Classes found: {class_list}")

# Shuffle and split
random.shuffle(data_pairs)
split_idx = int(len(data_pairs) * 0.8)
train_pairs = data_pairs[:split_idx]
val_pairs = data_pairs[split_idx:]

def process_pair(pair, split):
    json_file, img_file = pair
    filename = os.path.basename(img_file)
    basename = os.path.splitext(filename)[0]
    
    # Copy image
    dst_img_path = os.path.join(IMAGES_DIR, split, filename)
    shutil.copy(img_file, dst_img_path)
    
    # Process label
    with open(json_file, 'r') as f:
        data = json.load(f)
        
    img_h = data['imageHeight']
    img_w = data['imageWidth']
    
    yolo_lines = []
    for shape in data['shapes']:
        label = shape['label']
        cls_id = class_to_id[label]
        points = shape['points']
        
        # Calculate bounding box from points
        x_coords = [p[0] for p in points]
        y_coords = [p[1] for p in points]
        
        x_min = min(x_coords)
        x_max = max(x_coords)
        y_min = min(y_coords)
        y_max = max(y_coords)
        
        # Convert to center x, center y, width, height (normalized)
        dw = 1.0 / img_w
        dh = 1.0 / img_h
        
        w = x_max - x_min
        h = y_max - y_min
        x_center = x_min + w / 2.0
        y_center = y_min + h / 2.0
        
        w *= dw
        h *= dh
        x_center *= dw
        y_center *= dh
        
        yolo_lines.append(f"{cls_id} {x_center} {y_center} {w} {h}")
        
    # Write label file
    dst_label_path = os.path.join(LABELS_DIR, split, f"{basename}.txt")
    with open(dst_label_path, 'w') as f:
        f.write('\n'.join(yolo_lines))

print("Processing train set...")
for pair in train_pairs:
    process_pair(pair, 'train')

print("Processing val set...")
for pair in val_pairs:
    process_pair(pair, 'val')

# 3. Create dataset.yaml
yaml_content = {
    'path': BASE_DIR,
    'train': 'images/train',
    'val': 'images/val',
    'names': {i: name for i, name in enumerate(class_list)}
}

yaml_path = os.path.join(BASE_DIR, 'dataset.yaml')
with open(yaml_path, 'w') as f:
    yaml.dump(yaml_content, f)

print(f"Dataset preparation complete. YAML saved to {yaml_path}")

# 4. Train YOLO
model = YOLO("yolov8n.pt") 
results = model.train(data=yaml_path, epochs=10, imgsz=640)
